# %%
# Import necessary libraries
import pandas as pd

# Load the data
df = pd.read_csv('customer_reviews.csv')

# View the first few rows of the data
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Get the data types of each column
print(df.dtypes)

# Perform summary statistics
print(df.describe())

# Plot the distribution of ratings
plt.figure(figsize=(8,6))
sns.distplot(df['Rating'])
plt.title('Distribution of Ratings')
plt.show()

# Plot the distribution of customer age
plt.figure(figsize=(8,6))
sns.distplot(df['Customer Age'])
plt.title('Distribution of Customer Age')
plt.show()

# Plot the top 10 categories by frequency
plt.figure(figsize=(10,8))
sns.countplot(x='Category', data=df, order=df['Category'].value_counts().index[:10])
plt.title('Top 10 Categories by Frequency')
plt.show()

# Plot the top 10 subcategories by frequency
plt.figure(figsize=(10,8))
sns.countplot(x='Subcategory1', data=df, order=df['Subcategory1'].value_counts().index[:10])
plt.title('Top 10 Subcategories by Frequency')
plt.show()

# Plot the sentiment analysis by channel
plt.figure(figsize=(8,6))
sns.countplot(x='Channel', hue='Recommend Flag', data=df)
plt.title('Sentiment Analysis by Channel')
plt.show()

# Plot the sentiment analysis by location
plt.figure(figsize=(8,6))
sns.countplot(x='Location', hue='Recommend Flag', data=df)
plt.title('Sentiment Analysis by Location')
plt.show()
